# %%
import os

from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
from langgraph import Graph
from deepagents import Agent, Tool, ToolConfig
from pydantic import BaseModel, Field
import httpx

# %% [markdown]
# ### Basic design
# 1. input/内容录入：链接/docx/txt，或者ocr处理pdf
# 2. 背景：生成关键词，检索其他相关内容、报道，添加反馈中间件选择合适的补充来源
# 3. 大纲：确定视频节奏/风格，附带时间戳、建议视频素材和抓手
# 4. 整体生成->分段修改（人类反馈中间件）
# 5. 多模态：根据对视频素材的建议从用户上传的文件中选择合适的素材推荐并匹配
